# %%
from pipeline import fetch_and_summarize
from crawl import ErrorModel

url = "https://fr.wikipedia.org/wiki/Napoléon_Ier"

result = await fetch_and_summarize(url)

if isinstance(result, ErrorModel):
    print("ERREUR :", result.error)
else:
    print(result["title"])
    print()
    print(result["summary"])
    print()
    print(result["uncertainty"]["summary_stats"])
    print()
    for span in result["uncertainty"]["uncertain_spans"][:5]:
        print(span)
# Out:
# [INIT].... → Crawl4AI 0.6.3
# [FETCH]... ↓ https://fr.wikipedia.org/wiki/Napoléon_Ier                                                           |
# ✓ | ⏱: 4.26s
# [SCRAPE].. ◆ https://fr.wikipedia.org/wiki/Napoléon_Ier                                                           |
# ✓ | ⏱: 0.72s
# [COMPLETE] ● https://fr.wikipedia.org/wiki/Napoléon_Ier                                                           |
# ✓ | ⏱: 4.98s
# Napoléon Ier — Wikipédia
#
# ...
